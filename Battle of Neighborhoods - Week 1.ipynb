# %% [markdown]
# # Coursera Capstone Project
#
# ## The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ### Part 1 : Introduction and Data Sections

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: # uncomment this line if you haven't completed the Foursquare API lab
# Libraries imported.

# %% [markdown]
# # 1.	Introduction Section :
# ### Description of  the business problem and a discussion of the background.

# %% [markdown]
# A friend of mine wanted to start a new eatery delivery in Doha, Qatar.   He wanted to spot the best area where he can start his business which can give his better oppurtunities to grow his business.  The idea is to start his business in a location where he can have access to most of the the restaurants with least distance from his delivery centre and how many delivery centres does he require so that non of the restaurant is more than 4 Kms, so that his delivery guys can reach any of the restuarant in a min required time without any delay.  Doha proper city has an area of 132 km/Sq where most of the main restaurants are located.

# %% [markdown]
# # 2. Data Section:¶
# ### Description of the data and how it will be used to solve the problem

# %% [markdown]
# ### Description of the Data:¶
#
# The following data is required to  answer the issues of the problem:
#
# - List of all restaurants in Doha with it's ID,Name, Address, landmark if any,latitude and longitude.
#
#
# ### How the data will be used to solve the problem
#
# The data will be used as follows:
# - The data will be used to find a centre point based on the clusters of the restaurents.
# - Since the main city area is 132 Km/Sq we will consider our radius of 12Km within Doha.

# %%
# Shenton Way, District 01, Singapore
address = 'Doha, Qatar'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Doha is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Doha is 25.2856329, 51.5264162.

# %%
neighborhood_latitude=latitude
neighborhood_longitude=longitude

CLIENT_ID = 'WTUBBNAE25SZR2DKVB0HSSV0UIQYE5MBKS45H1FHV1LVOBGZ' # your Foursquare ID
CLIENT_SECRET = 'DE3F2DGXRHKHJOXYA2DIBZNP023DUBUZOFP4DZQZSBNRCZ1G' # your Foursquare Secret
ACCESS_TOKEN = '1RRPRNZE55WZUODPP2MG1BRILZIUZ3PZHAGDXTXW5GZURDIZ' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 200 # limit of number of venues returned by Foursquare API
radius = 12000 # define radius
search_query = 'Restaurant'

# create URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WTUBBNAE25SZR2DKVB0HSSV0UIQYE5MBKS45H1FHV1LVOBGZ&client_secret=DE3F2DGXRHKHJOXYA2DIBZNP023DUBUZOFP4DZQZSBNRCZ1G&ll=25.2856329,51.5264162&oauth_token=1RRPRNZE55WZUODPP2MG1BRILZIUZ3PZHAGDXTXW5GZURDIZ&v=20180604&query=Restaurant&radius=12000&limit=200'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e30203a8f5af04c3acc372'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '514d83a9e4b0fb270fbdf0e0',
#     'name': 'Al-Hamra Restaurant (مطعم الحمراء)',
#     'location': {'address': 'Alrayyan Road',
#      'lat': 25.28853116475642,
#      'lng': 51.52174543576032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28853116475642,
#        'lng': 51.52174543576032}],
#      'distance': 570,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Alrayyan Road', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4cb73a61589f236ada423d3d',
#     'name': 'Al Adhamiyah Iraqi Restaurant (مطعم الأعظمية العراقي)',
#     'location': {'address': 'Souq Wakif',
#      'lat': 25.286277836726285,
#      'lng': 51.531792464940104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.286277836726285,
#        'lng': 51.531792464940104}],
#      'distance': 545,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Wakif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '55c39c6c498ec87098f437a5',
#     'name': 'Punjab Restaurant (مطعم بنجاب)',
#     'location': {'lat': 25.283565528450293,
#      'lng': 51.52351147593809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.283565528450293,
#        'lng': 51.52351147593809}],
#      'distance': 372,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '52e81612bcbc57f1066b79f8',
#       'name': 'Pakistani Restaurant',
#       'pluralName': 'Pakistani Restaurants',
#       'shortName': 'Pakistani',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '53d7d0e8498eb348d50d3016',
#     'name': 'AlMurjan Restaurant',
#     'location': {'lat': 25.2861764407817,
#      'lng': 51.531567432734676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.2861764407817,
#        'lng': 51.531567432734676}],
#      'distance': 522,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['الدوحة']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#       'name': 'Lebanese Restaurant',
#       'pluralName': 'Lebanese Restaurants',
#       'shortName': 'Lebanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4f72edd1e4b06e8c1d9aed14',
#     'name': 'Tawash Restaurant (مطعم طواش)',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.28682581526963,
#      'lng': 51.53269153733677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28682581526963,
#        'lng': 51.53269153733677}],
#      'distance': 645,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d6d360ecb7a8cfa4efa5b79',
#     'name': 'Sanaa Restaurant',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.286240477384805,
#      'lng': 51.53253414577876,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.286240477384805,
#        'lng': 51.53253414577876}],
#      'distance': 619,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4cd02b885b5ca35d69397af0',
#     'name': 'Minang Indonesian Restaurant',
#     'location': {'address': 'Barahat Al Jufairi',
#      'crossStreet': 'Al Asmakh St.',
#      'lat': 25.28144044773413,
#      'lng': 51.53206389678295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28144044773413,
#        'lng': 51.53206389678295}],
#      'distance': 735,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Barahat Al Jufairi (Al Asmakh St.)', 'الدوحة']},
#     'categories': [{'id': '4deefc054765f83613cdba6f',
#       'name': 'Indonesian Restaurant',
#       'pluralName': 'Indonesian Restaurants',
#       'shortName': 'Indonesian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indonesian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5a9987c54940bc2ab2a2f15b',
#     'name': 'Aloosh Iraqi Restaurant (مطعم علوش العراقي)',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.28862,
#      'lng': 51.532085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28862,
#        'lng': 51.532085}],
#      'distance': 660,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4cab505876d3a09310162b6b',
#     'name': 'Bandar Aden Restaurant (مطعم بندر عدن للمأكولات اليمنية)',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.28961363564512,
#      'lng': 51.532939432457724,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28961363564512,
#        'lng': 51.532939432457724}],
#      'distance': 792,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4cd2a40b158c5481c6ffafe4',
#     'name': 'Al Mashrabiya Restaurant',
#     'location': {'address': 'Al Souq St.',
#      'lat': 25.28637990996039,
#      'lng': 51.53265515158981,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28637990996039,
#        'lng': 51.53265515158981}],
#      'distance': 633,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Souq St.', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4c129781a1010f478f244918',
#     'name': 'Al Tayyab Restaurant',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.287305,
#      'lng': 51.533683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.287305,
#        'lng': 51.533683}],
#      'distance': 754,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d10b941735',
#       'name': 'Falafel Restaurant',
#       'pluralName': 'Falafel Restaurants',
#       'shortName': 'Falafel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '501c35c3e4b004c545239c8a',
#     'name': 'MRA Bakery, Restaurant & Sweets',
#     'location': {'address': 'Old all ghanum',
#      'lat': 25.280302242654546,
#      'lng': 51.53692363718852,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.280302242654546,
#        'lng': 51.53692363718852}],
#      'distance': 1212,
#      'postalCode': '37451',
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Old all ghanum', 'الدوحة 37451']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '539b441f498e78925a2deb36',
#     'name': 'Shebestan Palace Restaurant (مطعم قصر شبستان)',
#     'location': {'lat': 25.287949466531728,
#      'lng': 51.533893049030155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.287949466531728,
#        'lng': 51.533893049030155}],
#      'distance': 795,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '594959e83b83074ee07884a6',
#     'name': 'Khaosan Thai Restaurant',
#     'location': {'address': 'Bin Mahmood',
#      'lat': 25.284365241343266,
#      'lng': 51.51152221239028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.284365241343266,
#        'lng': 51.51152221239028}],
#      'distance': 1505,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Bin Mahmood', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4b7198d1f964a520fb4f2de3',
#     'name': 'Soy Restaurant',
#     'location': {'address': 'Souq Waqif',
#      'lat': 25.285017208883726,
#      'lng': 51.53548812985299,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285017208883726,
#        'lng': 51.53548812985299}],
#      'distance': 915,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Waqif', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4eabe3d861af01ea2af7c2a6',
#     'name': 'Shebestan Palace Restaurant',
#     'location': {'address': 'Al Sadd',
#      'crossStreet': 'Al Sadd St',
#      'lat': 25.280947565058884,
#      'lng': 51.5041646144501,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.280947565058884,
#        'lng': 51.5041646144501}],
#      'distance': 2299,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Sadd (Al Sadd St)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d3f1a7484d46ea8ce51155d',
#     'name': 'Sara Restaurant (مطعم ساره)',
#     'location': {'address': 'Frig Abdul Aziz',
#      'crossStreet': 'Al Muntazah Street',
#      'lat': 25.27646910785231,
#      'lng': 51.52425521206549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.27646910785231,
#        'lng': 51.52425521206549}],
#      'distance': 1043,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Frig Abdul Aziz (Al Muntazah Street)', 'الدوحة']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f8',
#       'name': 'Pakistani Restaurant',
#       'pluralName': 'Pakistani Restaurants',
#       'shortName': 'Pakistani',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4cd327759828b60cf702d484',
#     'name': 'Choices Restaurant',
#     'location': {'address': 'Oryx Doha Hotel',
#      'crossStreet': 'B Ring Rd.',
#      'lat': 25.27688509798818,
#      'lng': 51.52014371917642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.27688509798818,
#        'lng': 51.52014371917642}],
#      'distance': 1160,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Oryx Doha Hotel (B Ring Rd.)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d39c583cc48224b69d0364f',
#     'name': 'The Great Chinese Wall Restaurant',
#     'location': {'address': 'The Centre',
#      'lat': 25.273636679177756,
#      'lng': 51.51500414985267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.273636679177756,
#        'lng': 51.51500414985267}],
#      'distance': 1761,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['The Centre', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d1b2e3cdd3637040ac4611a',
#     'name': 'Jakarta Restaurant',
#     'location': {'address': 'Ibn mahmood',
#      'crossStreet': 'badriya signal',
#      'lat': 25.282276025171118,
#      'lng': 51.515058672883356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.282276025171118,
#        'lng': 51.515058672883356}],
#      'distance': 1202,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Ibn mahmood (badriya signal)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5995e2e8a9fe1257eb1a200f',
#     'name': 'Pilawoos Restaurant',
#     'location': {'address': 'Al Ikhaa Street',
#      'crossStreet': 'Bin Mahmood',
#      'lat': 25.285599,
#      'lng': 51.514597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285599,
#        'lng': 51.514597}],
#      'distance': 1189,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Ikhaa Street (Bin Mahmood)', 'الدوحة']},
#     'categories': [{'id': '5413605de4b0ae91d18581a9',
#       'name': 'Sri Lankan Restaurant',
#       'pluralName': 'Sri Lankan Restaurants',
#       'shortName': 'Sri Lankan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '50fc3c9be4b0ff3fce8f2e1e',
#     'name': 'Marwa Restaurant',
#     'location': {'address': 'Bin Mahmoud',
#      'lat': 25.28227424621582,
#      'lng': 51.51500701904297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28227424621582,
#        'lng': 51.51500701904297}],
#      'distance': 1207,
#      'cc': 'QA',
#      'country': 'قطر',
#      'formattedAddress': ['Bin Mahmoud']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d582f8c380ab1f7262505f5',
#     'name': 'Beirut Restaurant (مطعم بيروت)',
#     'location': {'address': 'Bin mahmoud',
#      'lat': 25.285031833528816,
#      'lng': 51.50890368570543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285031833528816,
#        'lng': 51.50890368570543}],
#      'distance': 1763,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Bin mahmoud', 'الدوحة']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#       'name': 'Lebanese Restaurant',
#       'pluralName': 'Lebanese Restaurants',
#       'shortName': 'Lebanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4e3d4ba1d164b52911aa63f4',
#     'name': 'Al Hameel Restaurant',
#     'location': {'address': 'B Ring Rd, Doha',
#      'lat': 25.274859139258936,
#      'lng': 51.522494970307754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.274859139258936,
#        'lng': 51.522494970307754}],
#      'distance': 1262,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['B Ring Rd, Doha', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4ee48b806da14e7d99cfb376',
#     'name': 'Jamal Restaurant',
#     'location': {'lat': 25.285236876107184,
#      'lng': 51.51310081923343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285236876107184,
#        'lng': 51.51310081923343}],
#      'distance': 1340,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['الدوحة']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f8',
#       'name': 'Pakistani Restaurant',
#       'pluralName': 'Pakistani Restaurants',
#       'shortName': 'Pakistani',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4ebad57e77c8100292c1a11b',
#     'name': 'Jabal Lebnan Restaurant',
#     'location': {'lat': 25.274215993847456,
#      'lng': 51.50504169631864,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.274215993847456,
#        'lng': 51.50504169631864}],
#      'distance': 2498,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#       'name': 'Lebanese Restaurant',
#       'pluralName': 'Lebanese Restaurants',
#       'shortName': 'Lebanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4bb77406941ad13a4cb020e3',
#     'name': 'Turkey Central Restaurant',
#     'location': {'address': 'Al Mirqab Al Jadeed St.',
#      'lat': 25.27351615287835,
#      'lng': 51.496270936102924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.27351615287835,
#        'lng': 51.496270936102924}],
#      'distance': 3320,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Mirqab Al Jadeed St.', 'الدوحة']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '512e2566e4b0f2029f6c29b8',
#     'name': 'Halo-Halo Special Coffee Shop &  Restaurant',
#     'location': {'lat': 25.271838780255752,
#      'lng': 51.52915659780892,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.271838780255752,
#        'lng': 51.52915659780892}],
#      'distance': 1560,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4f22de5fe4b01dc949f6fbdd',
#     'name': 'Aryaas Vegetarian Restaurant',
#     'location': {'address': 'Al Meera',
#      'lat': 25.271792800605056,
#      'lng': 51.52901713088832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.271792800605056,
#        'lng': 51.52901713088832}],
#      'distance': 1562,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Meera', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4ed7e3f06da14054c343ea85',
#     'name': 'Sidi Bou Said Tunisian Restaurant',
#     'location': {'address': 'Al Mirqab Al Jadeed Street',
#      'crossStreet': 'مطعم سيدي بو سعيد',
#      'lat': 25.27460886420889,
#      'lng': 51.506167137688166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.27460886420889,
#        'lng': 51.506167137688166}],
#      'distance': 2379,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Mirqab Al Jadeed Street (مطعم سيدي بو سعيد)',
#       'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4e4bd8e8d22d8354d6f1e582',
#     'name': 'Bukhara Restaurant (مطعم بخارا)',
#     'location': {'address': 'Al Khuwair',
#      'crossStreet': 'Al Markhiya St',
#      'lat': 25.313280928700188,
#      'lng': 51.513790088412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.313280928700188,
#        'lng': 51.513790088412}],
#      'distance': 3329,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Khuwair (Al Markhiya St)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4f54a4eee4b092981036e675',
#     'name': 'Restaurant and Mashawi Al-Tayeb',
#     'location': {'lat': 25.28710239004842,
#      'lng': 51.53296367268971,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28710239004842,
#        'lng': 51.53296367268971}],
#      'distance': 679,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5b8f0939a4ba7c002c301941',
#     'name': 'Turkey Restaurant',
#     'location': {'address': 'Najma Street',
#      'lat': 25.273244,
#      'lng': 51.537012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.273244,
#        'lng': 51.537012}],
#      'distance': 1743,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Najma Street', 'الدوحة']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5f57d220a716fa600c19f7bf',
#     'name': "O' Glacee Pool Bar And Restaurant",
#     'location': {'lat': 25.285309,
#      'lng': 51.530293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285309,
#        'lng': 51.530293}],
#      'distance': 391,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5d23a4887ad19400236cd6c0',
#     'name': "Max's Restaurant - Al Sadd",
#     'location': {'address': 'Al Sadd Mall, Ground Floor, Al Diffaf St, Al Sadd',
#      'lat': 25.281881,
#      'lng': 51.500387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.281881,
#        'lng': 51.500387}],
#      'distance': 2653,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Sadd Mall, Ground Floor, Al Diffaf St, Al Sadd',
#       'الدوحة']},
#     'categories': [{'id': '4eb1bd1c3b7b55596b4a748f',
#       'name': 'Filipino Restaurant',
#       'pluralName': 'Filipino Restaurants',
#       'shortName': 'Filipino',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/filipino_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4c4daaf192b6a59320e3a56e',
#     'name': 'Thai Smile Restaurant',
#     'location': {'address': 'Umm Ghuwailina St.',
#      'lat': 25.273529009039912,
#      'lng': 51.54498146490315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.273529009039912,
#        'lng': 51.54498146490315}],
#      'distance': 2303,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Umm Ghuwailina St.', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4ee476319911944901136a93',
#     'name': 'Jabeer Sweets and Restaurant',
#     'location': {'address': 'Ras Abou Aboud',
#      'crossStreet': 'B Ring Road',
#      'lat': 25.282133841714426,
#      'lng': 51.54456897609051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.282133841714426,
#        'lng': 51.54456897609051}],
#      'distance': 1868,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Ras Abou Aboud (B Ring Road)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d1c9f3b7e10a35dc9c80083',
#     'name': 'Thai Snack Restaurant',
#     'location': {'address': 'Al Nasser',
#      'lat': 25.274625221267165,
#      'lng': 51.50661779211611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.274625221267165,
#        'lng': 51.50661779211611}],
#      'distance': 2339,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Nasser', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '50b185b3e4b08106f37c6417',
#     'name': 'Alzarka Restaurant (مطعم الزرقاء)',
#     'location': {'lat': 25.280517193528752,
#      'lng': 51.54391163022229,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.280517193528752,
#        'lng': 51.54391163022229}],
#      'distance': 1850,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5914ad56fdb9a720410c87ab',
#     'name': 'Turkish Laayonak Restaurant',
#     'location': {'address': 'old al ghainim',
#      'crossStreet': 'sana signal',
#      'lat': 25.278421,
#      'lng': 51.543396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.278421,
#        'lng': 51.543396}],
#      'distance': 1888,
#      'postalCode': '008031',
#      'cc': 'QA',
#      'neighborhood': 'أم الغويلينة',
#      'city': 'doha',
#      'state': 'corniche',
#      'country': 'قطر',
#      'formattedAddress': ['old al ghainim (sana signal)', 'doha 008031']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4c60168e3986e21eee64934f',
#     'name': 'Al Khaima Restaurant (مطعم الخيمة)',
#     'location': {'address': 'Al Sadd Street',
#      'crossStreet': 'Al Sadd St.',
#      'lat': 25.28081779891852,
#      'lng': 51.49560632629747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.28081779891852,
#        'lng': 51.49560632629747}],
#      'distance': 3147,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Sadd Street (Al Sadd St.)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4e76ca51ae60c32851b98966',
#     'name': 'King Restaurant',
#     'location': {'address': 'Al Mansoura',
#      'crossStreet': 'at Al Mansoura St.',
#      'lat': 25.2687405160447,
#      'lng': 51.53205871582031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.2687405160447,
#        'lng': 51.53205871582031}],
#      'distance': 1964,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Al Mansoura (at Al Mansoura St.)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4ee0fd7e49010b29921ba016',
#     'name': 'Seasons Restaurant',
#     'location': {'address': 'Mövenpick Hotel Doha',
#      'crossStreet': 'Opposite the Museum of Islamic Arts',
#      'lat': 25.290198496797093,
#      'lng': 51.54453780426029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.290198496797093,
#        'lng': 51.54453780426029}],
#      'distance': 1893,
#      'postalCode': '24220',
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Mövenpick Hotel Doha (Opposite the Museum of Islamic Arts)',
#       'الدوحة 24220']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57271140'},
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '532fd03a11d2a4312653803b',
#     'name': 'Baraha restaurant',
#     'location': {'address': 'Zubarah Hotel',
#      'crossStreet': 'Al Rawabi St.',
#      'lat': 25.270136744822747,
#      'lng': 51.517638547963735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.270136744822747,
#        'lng': 51.517638547963735}],
#      'distance': 1938,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Zubarah Hotel (Al Rawabi St.)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5f10840a268a06488738ccf6',
#     'name': 'Sora Restaurant',
#     'location': {'address': 'Park Hyatt Hotel',
#      'lat': 25.284412,
#      'lng': 51.527897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.284412,
#        'lng': 51.527897}],
#      'distance': 201,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Park Hyatt Hotel', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4d639744a45b5481610f032d',
#     'name': 'Al Shami Home Restaurant',
#     'location': {'address': 'P.O. Box 80587',
#      'crossStreet': 'C Ring Rd.',
#      'lat': 25.275848626289864,
#      'lng': 51.5088677193207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.275848626289864,
#        'lng': 51.5088677193207}],
#      'distance': 2075,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['P.O. Box 80587 (C Ring Rd.)', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '58c055f90b7e93326677107e',
#     'name': 'Al Shabrawi Restaurant (مطعم الشبراوي)',
#     'location': {'lat': 25.276478,
#      'lng': 51.544117,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.276478,
#        'lng': 51.544117}],
#      'distance': 2052,
#      'cc': 'QA',
#      'country': 'قطر'},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '50f99b00e4b073809e59d1a5',
#     'name': 'Puerto Galera Restaurant',
#     'location': {'address': 'Mansoura',
#      'lat': 25.269890395920548,
#      'lng': 51.533452512946845,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.269890395920548,
#        'lng': 51.533452512946845}],
#      'distance': 1890,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Mansoura', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '5b6180586f0aa2002da0e5bc',
#     'name': 'Pak Pakwan Restaurant',
#     'location': {'lat': 25.285741,
#      'lng': 51.523407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.285741,
#        'lng': 51.523407}],
#      'distance': 303,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['الدوحة']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f8',
#       'name': 'Pakistani Restaurant',
#       'pluralName': 'Pakistani Restaurants',
#       'shortName': 'Pakistani',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False},
#    {'id': '4c70096bd274b60c3d4ed80d',
#     'name': 'Layali Restaurant',
#     'location': {'address': 'Souq Najd, Salwa Road',
#      'lat': 25.269321942589983,
#      'lng': 51.505545659738445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 25.269321942589983,
#        'lng': 51.505545659738445}],
#      'distance': 2776,
#      'cc': 'QA',
#      'city': 'الدوحة',
#      'state': 'الدوحة',
#      'country': 'قطر',
#      'formattedAddress': ['Souq Najd, Salwa Road', 'الدوحة']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1625489923',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
#venues
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-35-b2247b82aca9>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id  \
# 0  514d83a9e4b0fb270fbdf0e0
# 1  4cb73a61589f236ada423d3d
# 2  55c39c6c498ec87098f437a5
# 3  53d7d0e8498eb348d50d3016
# 4  4f72edd1e4b06e8c1d9aed14
#
#                                                 name  \
# 0                 Al-Hamra Restaurant (مطعم الحمراء)
# 1  Al Adhamiyah Iraqi Restaurant (مطعم الأعظمية ا...
# 2                     Punjab Restaurant (مطعم بنجاب)
# 3                                AlMurjan Restaurant
# 4                      Tawash Restaurant (مطعم طواش)
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...  v-1625489478    False
# 1  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...  v-1625489478    False
# 2  [{'id': '52e81612bcbc57f1066b79f8', 'name': 'P...  v-1625489478    False
# 3  [{'id': '58daa1558bbb0b01f18ec1cd', 'name': 'L...  v-1625489478    False
# 4  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...  v-1625489478    False
#
#   location.address  location.lat  location.lng  \
# 0    Alrayyan Road     25.288531     51.521745
# 1       Souq Wakif     25.286278     51.531792
# 2              NaN     25.283566     51.523511
# 3              NaN     25.286176     51.531567
# 4       Souq Waqif     25.286826     51.532692
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 25.28853116475642...                570
# 1  [{'label': 'display', 'lat': 25.28627783672628...                545
# 2  [{'label': 'display', 'lat': 25.28356552845029...                372
# 3  [{'label': 'display', 'lat': 25.2861764407817,...                522
# 4  [{'label': 'display', 'lat': 25.28682581526963...                645
#
#   location.cc location.city location.state location.country  \
# 0          QA        الدوحة         الدوحة              قطر
# 1          QA        الدوحة         الدوحة              قطر
# 2          QA           NaN            NaN              قطر
# 3          QA        الدوحة         الدوحة              قطر
# 4          QA        الدوحة         الدوحة              قطر
#
#   location.formattedAddress location.crossStreet location.postalCode  \
# 0   [Alrayyan Road, الدوحة]                  NaN                 NaN
# 1      [Souq Wakif, الدوحة]                  NaN                 NaN
# 2                       NaN                  NaN                 NaN
# 3                  [الدوحة]                  NaN                 NaN
# 4      [Souq Waqif, الدوحة]                  NaN                 NaN
#
#   location.neighborhood venuePage.id
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                  Al-Hamra Restaurant (مطعم الحمراء)
# 1   Al Adhamiyah Iraqi Restaurant (مطعم الأعظمية ا...
# 2                      Punjab Restaurant (مطعم بنجاب)
# 3                                 AlMurjan Restaurant
# 4                       Tawash Restaurant (مطعم طواش)
# 5                                    Sanaa Restaurant
# 6                        Minang Indonesian Restaurant
# 7         Aloosh Iraqi Restaurant (مطعم علوش العراقي)
# 8   Bandar Aden Restaurant (مطعم بندر عدن للمأكولا...
# 9                            Al Mashrabiya Restaurant
# 10                               Al Tayyab Restaurant
# 11                    MRA Bakery, Restaurant & Sweets
# 12      Shebestan Palace Restaurant (مطعم قصر شبستان)
# 13                            Khaosan Thai Restaurant
# 14                                     Soy Restaurant
# 15                        Shebestan Palace Restaurant
# 16                        Sara Restaurant (مطعم ساره)
# 17                                 Choices Restaurant
# 18                  The Great Chinese Wall Restaurant
# 19                                 Jakarta Restaurant
# 20                                Pilawoos Restaurant
# 21                                   Marwa Restaurant
# 22                     Beirut Restaurant (مطعم بيروت)
# 23                               Al Hameel Restaurant
# 24                                   Jamal Restaurant
# 25                            Jabal Lebnan Restaurant
# 26                          Turkey Central Restaurant
# 27        Halo-Halo Special Coffee Shop &  Restaurant
# 28                       Aryaas Vegetarian Restaurant
# 29                  Sidi Bou Said Tunisian Restaurant
# 30                    Bukhara Restaurant (مطعم بخارا)
# 31                    Restaurant and Mashawi Al-Tayeb
# 32                                  Turkey Restaurant
# 33                  O' Glacee Pool Bar And Restaurant
# 34                         Max's Restaurant - Al Sadd
# 35                              Thai Smile Restaurant
# 36                       Jabeer Sweets and Restaurant
# 37                              Thai Snack Restaurant
# 38                  Alzarka Restaurant (مطعم الزرقاء)
# 39                        Turkish Laayonak Restaurant
# 40                 Al Khaima Restaurant (مطعم الخيمة)
# 41                                    King Restaurant
# 42                                 Seasons Restaurant
# 43                                  Baraha restaurant
# 44                                    Sora Restaurant
# 45                           Al Shami Home Restaurant
# 46             Al Shabrawi Restaurant (مطعم الشبراوي)
# 47                           Puerto Galera Restaurant
# 48                              Pak Pakwan Restaurant
# 49                                  Layali Restaurant
#
#                    categories  \
# 0   Middle Eastern Restaurant
# 1   Middle Eastern Restaurant
# 2        Pakistani Restaurant
# 3         Lebanese Restaurant
# 4   Middle Eastern Restaurant
# 5   Middle Eastern Restaurant
# 6       Indonesian Restaurant
# 7   Middle Eastern Restaurant
# 8   Middle Eastern Restaurant
# 9                    Tea Room
# 10         Falafel Restaurant
# 11          Indian Restaurant
# 12                 Restaurant
# 13            Thai Restaurant
# 14                 Restaurant
# 15  Middle Eastern Restaurant
# 16       Pakistani Restaurant
# 17  Middle Eastern Restaurant
# 18           Asian Restaurant
# 19          Food & Drink Shop
# 20      Sri Lankan Restaurant
# 21        Fried Chicken Joint
# 22        Lebanese Restaurant
# 23          Indian Restaurant
# 24       Pakistani Restaurant
# 25        Lebanese Restaurant
# 26         Turkish Restaurant
# 27           Asian Restaurant
# 28          Indian Restaurant
# 29   Mediterranean Restaurant
# 30          Indian Restaurant
# 31  Middle Eastern Restaurant
# 32         Turkish Restaurant
# 33                      Hotel
# 34        Filipino Restaurant
# 35            Thai Restaurant
# 36                 Restaurant
# 37           Asian Restaurant
# 38           Asian Restaurant
# 39         Turkish Restaurant
# 40  Middle Eastern Restaurant
# 41          Indian Restaurant
# 42                 Restaurant
# 43                 Restaurant
# 44        Japanese Restaurant
# 45  Middle Eastern Restaurant
# 46         Turkish Restaurant
# 47           Asian Restaurant
# 48       Pakistani Restaurant
# 49  Middle Eastern Restaurant
#
#                                               address        lat        lng  \
# 0                                       Alrayyan Road  25.288531  51.521745
# 1                                          Souq Wakif  25.286278  51.531792
# 2                                                 NaN  25.283566  51.523511
# 3                                                 NaN  25.286176  51.531567
# 4                                          Souq Waqif  25.286826  51.532692
# 5                                          Souq Waqif  25.286240  51.532534
# 6                                  Barahat Al Jufairi  25.281440  51.532064
# 7                                          Souq Waqif  25.288620  51.532085
# 8                                          Souq Waqif  25.289614  51.532939
# 9                                         Al Souq St.  25.286380  51.532655
# 10                                         Souq Waqif  25.287305  51.533683
# 11                                     Old all ghanum  25.280302  51.536924
# 12                                                NaN  25.287949  51.533893
# 13                                        Bin Mahmood  25.284365  51.511522
# 14                                         Souq Waqif  25.285017  51.535488
# 15                                            Al Sadd  25.280948  51.504165
# 16                                    Frig Abdul Aziz  25.276469  51.524255
# 17                                    Oryx Doha Hotel  25.276885  51.520144
# 18                                         The Centre  25.273637  51.515004
# 19                                        Ibn mahmood  25.282276  51.515059
# 20                                    Al Ikhaa Street  25.285599  51.514597
# 21                                        Bin Mahmoud  25.282274  51.515007
# 22                                        Bin mahmoud  25.285032  51.508904
# 23                                    B Ring Rd, Doha  25.274859  51.522495
# 24                                                NaN  25.285237  51.513101
# 25                                                NaN  25.274216  51.505042
# 26                            Al Mirqab Al Jadeed St.  25.273516  51.496271
# 27                                                NaN  25.271839  51.529157
# 28                                           Al Meera  25.271793  51.529017
# 29                         Al Mirqab Al Jadeed Street  25.274609  51.506167
# 30                                         Al Khuwair  25.313281  51.513790
# 31                                                NaN  25.287102  51.532964
# 32                                       Najma Street  25.273244  51.537012
# 33                                                NaN  25.285309  51.530293
# 34  Al Sadd Mall, Ground Floor, Al Diffaf St, Al Sadd  25.281881  51.500387
# 35                                 Umm Ghuwailina St.  25.273529  51.544981
# 36                                     Ras Abou Aboud  25.282134  51.544569
# 37                                          Al Nasser  25.274625  51.506618
# 38                                                NaN  25.280517  51.543912
# 39                                     old al ghainim  25.278421  51.543396
# 40                                     Al Sadd Street  25.280818  51.495606
# 41                                        Al Mansoura  25.268741  51.532059
# 42                               Mövenpick Hotel Doha  25.290198  51.544538
# 43                                      Zubarah Hotel  25.270137  51.517639
# 44                                   Park Hyatt Hotel  25.284412  51.527897
# 45                                     P.O. Box 80587  25.275849  51.508868
# 46                                                NaN  25.276478  51.544117
# 47                                           Mansoura  25.269890  51.533453
# 48                                                NaN  25.285741  51.523407
# 49                              Souq Najd, Salwa Road  25.269322  51.505546
#
#                                        labeledLatLngs  distance  cc    city  \
# 0   [{'label': 'display', 'lat': 25.28853116475642...       570  QA  الدوحة
# 1   [{'label': 'display', 'lat': 25.28627783672628...       545  QA  الدوحة
# 2   [{'label': 'display', 'lat': 25.28356552845029...       372  QA     NaN
# 3   [{'label': 'display', 'lat': 25.2861764407817,...       522  QA  الدوحة
# 4   [{'label': 'display', 'lat': 25.28682581526963...       645  QA  الدوحة
# 5   [{'label': 'display', 'lat': 25.28624047738480...       619  QA  الدوحة
# 6   [{'label': 'display', 'lat': 25.28144044773413...       735  QA  الدوحة
# 7   [{'label': 'display', 'lat': 25.28862, 'lng': ...       660  QA  الدوحة
# 8   [{'label': 'display', 'lat': 25.28961363564512...       792  QA  الدوحة
# 9   [{'label': 'display', 'lat': 25.28637990996039...       633  QA  الدوحة
# 10  [{'label': 'display', 'lat': 25.287305, 'lng':...       754  QA  الدوحة
# 11  [{'label': 'display', 'lat': 25.28030224265454...      1212  QA  الدوحة
# 12  [{'label': 'display', 'lat': 25.28794946653172...       795  QA     NaN
# 13  [{'label': 'display', 'lat': 25.28436524134326...      1505  QA  الدوحة
# 14  [{'label': 'display', 'lat': 25.28501720888372...       915  QA  الدوحة
# 15  [{'label': 'display', 'lat': 25.28094756505888...      2299  QA  الدوحة
# 16  [{'label': 'display', 'lat': 25.27646910785231...      1043  QA  الدوحة
# 17  [{'label': 'display', 'lat': 25.27688509798818...      1160  QA  الدوحة
# 18  [{'label': 'display', 'lat': 25.27363667917775...      1761  QA  الدوحة
# 19  [{'label': 'display', 'lat': 25.28227602517111...      1202  QA  الدوحة
# 20  [{'label': 'display', 'lat': 25.285599, 'lng':...      1189  QA  الدوحة
# 21  [{'label': 'display', 'lat': 25.28227424621582...      1207  QA     NaN
# 22  [{'label': 'display', 'lat': 25.28503183352881...      1763  QA  الدوحة
# 23  [{'label': 'display', 'lat': 25.27485913925893...      1262  QA  الدوحة
# 24  [{'label': 'display', 'lat': 25.28523687610718...      1340  QA  الدوحة
# 25  [{'label': 'display', 'lat': 25.27421599384745...      2498  QA     NaN
# 26  [{'label': 'display', 'lat': 25.27351615287835...      3320  QA  الدوحة
# 27  [{'label': 'display', 'lat': 25.27183878025575...      1560  QA     NaN
# 28  [{'label': 'display', 'lat': 25.27179280060505...      1562  QA  الدوحة
# 29  [{'label': 'display', 'lat': 25.27460886420889...      2379  QA  الدوحة
# 30  [{'label': 'display', 'lat': 25.31328092870018...      3329  QA  الدوحة
# 31  [{'label': 'display', 'lat': 25.28710239004842...       679  QA     NaN
# 32  [{'label': 'display', 'lat': 25.273244, 'lng':...      1743  QA  الدوحة
# 33  [{'label': 'display', 'lat': 25.285309, 'lng':...       391  QA  الدوحة
# 34  [{'label': 'display', 'lat': 25.281881, 'lng':...      2653  QA  الدوحة
# 35  [{'label': 'display', 'lat': 25.27352900903991...      2303  QA  الدوحة
# 36  [{'label': 'display', 'lat': 25.28213384171442...      1868  QA  الدوحة
# 37  [{'label': 'display', 'lat': 25.27462522126716...      2339  QA  الدوحة
# 38  [{'label': 'display', 'lat': 25.28051719352875...      1850  QA     NaN
# 39  [{'label': 'display', 'lat': 25.278421, 'lng':...      1888  QA    doha
# 40  [{'label': 'display', 'lat': 25.28081779891852...      3147  QA  الدوحة
# 41  [{'label': 'display', 'lat': 25.2687405160447,...      1964  QA  الدوحة
# 42  [{'label': 'display', 'lat': 25.29019849679709...      1893  QA  الدوحة
# 43  [{'label': 'display', 'lat': 25.27013674482274...      1938  QA  الدوحة
# 44  [{'label': 'display', 'lat': 25.284412, 'lng':...       201  QA  الدوحة
# 45  [{'label': 'display', 'lat': 25.27584862628986...      2075  QA  الدوحة
# 46  [{'label': 'display', 'lat': 25.276478, 'lng':...      2052  QA     NaN
# 47  [{'label': 'display', 'lat': 25.26989039592054...      1890  QA  الدوحة
# 48  [{'label': 'display', 'lat': 25.285741, 'lng':...       303  QA  الدوحة
# 49  [{'label': 'display', 'lat': 25.26932194258998...      2776  QA  الدوحة
#
#        state country                                   formattedAddress  \
# 0     الدوحة     قطر                            [Alrayyan Road, الدوحة]
# 1     الدوحة     قطر                               [Souq Wakif, الدوحة]
# 2        NaN     قطر                                                NaN
# 3     الدوحة     قطر                                           [الدوحة]
# 4     الدوحة     قطر                               [Souq Waqif, الدوحة]
# 5     الدوحة     قطر                               [Souq Waqif, الدوحة]
# 6     الدوحة     قطر       [Barahat Al Jufairi (Al Asmakh St.), الدوحة]
# 7     الدوحة     قطر                               [Souq Waqif, الدوحة]
# 8     الدوحة     قطر                               [Souq Waqif, الدوحة]
# 9     الدوحة     قطر                              [Al Souq St., الدوحة]
# 10    الدوحة     قطر                               [Souq Waqif, الدوحة]
# 11    الدوحة     قطر                     [Old all ghanum, الدوحة 37451]
# 12       NaN     قطر                                                NaN
# 13    الدوحة     قطر                              [Bin Mahmood, الدوحة]
# 14    الدوحة     قطر                               [Souq Waqif, الدوحة]
# 15    الدوحة     قطر                     [Al Sadd (Al Sadd St), الدوحة]
# 16    الدوحة     قطر     [Frig Abdul Aziz (Al Muntazah Street), الدوحة]
# 17    الدوحة     قطر             [Oryx Doha Hotel (B Ring Rd.), الدوحة]
# 18    الدوحة     قطر                               [The Centre, الدوحة]
# 19    الدوحة     قطر             [Ibn mahmood (badriya signal), الدوحة]
# 20    الدوحة     قطر            [Al Ikhaa Street (Bin Mahmood), الدوحة]
# 21       NaN     قطر                                      [Bin Mahmoud]
# 22    الدوحة     قطر                              [Bin mahmoud, الدوحة]
# 23    الدوحة     قطر                          [B Ring Rd, Doha, الدوحة]
# 24    الدوحة     قطر                                           [الدوحة]
# 25       NaN     قطر                                                NaN
# 26    الدوحة     قطر                  [Al Mirqab Al Jadeed St., الدوحة]
# 27       NaN     قطر                                                NaN
# 28    الدوحة     قطر                                 [Al Meera, الدوحة]
# 29    الدوحة     قطر  [Al Mirqab Al Jadeed Street (مطعم سيدي بو سعيد...
# 30    الدوحة     قطر              [Al Khuwair (Al Markhiya St), الدوحة]
# 31       NaN     قطر                                                NaN
# 32    الدوحة     قطر                             [Najma Street, الدوحة]
# 33    الدوحة     قطر                                           [الدوحة]
# 34    الدوحة     قطر  [Al Sadd Mall, Ground Floor, Al Diffaf St, Al ...
# 35    الدوحة     قطر                       [Umm Ghuwailina St., الدوحة]
# 36    الدوحة     قطر             [Ras Abou Aboud (B Ring Road), الدوحة]
# 37    الدوحة     قطر                                [Al Nasser, الدوحة]
# 38       NaN     قطر                                                NaN
# 39  corniche     قطر        [old al ghainim (sana signal), doha 008031]
# 40    الدوحة     قطر             [Al Sadd Street (Al Sadd St.), الدوحة]
# 41    الدوحة     قطر         [Al Mansoura (at Al Mansoura St.), الدوحة]
# 42    الدوحة     قطر  [Mövenpick Hotel Doha (Opposite the Museum of ...
# 43    الدوحة     قطر            [Zubarah Hotel (Al Rawabi St.), الدوحة]
# 44    الدوحة     قطر                         [Park Hyatt Hotel, الدوحة]
# 45    الدوحة     قطر              [P.O. Box 80587 (C Ring Rd.), الدوحة]
# 46       NaN     قطر                                                NaN
# 47    الدوحة     قطر                                 [Mansoura, الدوحة]
# 48    الدوحة     قطر                                           [الدوحة]
# 49    الدوحة     قطر                    [Souq Najd, Salwa Road, الدوحة]
#
#                             crossStreet postalCode  neighborhood  \
# 0                                   NaN        NaN           NaN
# 1                                   NaN        NaN           NaN
# 2                                   NaN        NaN           NaN
# 3                                   NaN        NaN           NaN
# 4                                   NaN        NaN           NaN
# 5                                   NaN        NaN           NaN
# 6                         Al Asmakh St.        NaN           NaN
# 7                                   NaN        NaN           NaN
# 8                                   NaN        NaN           NaN
# 9                                   NaN        NaN           NaN
# 10                                  NaN        NaN           NaN
# 11                                  NaN      37451           NaN
# 12                                  NaN        NaN           NaN
# 13                                  NaN        NaN           NaN
# 14                                  NaN        NaN           NaN
# 15                           Al Sadd St        NaN           NaN
# 16                   Al Muntazah Street        NaN           NaN
# 17                           B Ring Rd.        NaN           NaN
# 18                                  NaN        NaN           NaN
# 19                       badriya signal        NaN           NaN
# 20                          Bin Mahmood        NaN           NaN
# 21                                  NaN        NaN           NaN
# 22                                  NaN        NaN           NaN
# 23                                  NaN        NaN           NaN
# 24                                  NaN        NaN           NaN
# 25                                  NaN        NaN           NaN
# 26                                  NaN        NaN           NaN
# 27                                  NaN        NaN           NaN
# 28                                  NaN        NaN           NaN
# 29                    مطعم سيدي بو سعيد        NaN           NaN
# 30                       Al Markhiya St        NaN           NaN
# 31                                  NaN        NaN           NaN
# 32                                  NaN        NaN           NaN
# 33                                  NaN        NaN           NaN
# 34                                  NaN        NaN           NaN
# 35                                  NaN        NaN           NaN
# 36                          B Ring Road        NaN           NaN
# 37                                  NaN        NaN           NaN
# 38                                  NaN        NaN           NaN
# 39                          sana signal     008031  أم الغويلينة
# 40                          Al Sadd St.        NaN           NaN
# 41                   at Al Mansoura St.        NaN           NaN
# 42  Opposite the Museum of Islamic Arts      24220           NaN
# 43                        Al Rawabi St.        NaN           NaN
# 44                                  NaN        NaN           NaN
# 45                           C Ring Rd.        NaN           NaN
# 46                                  NaN        NaN           NaN
# 47                                  NaN        NaN           NaN
# 48                                  NaN        NaN           NaN
# 49                                  NaN        NaN           NaN
#
#                           id
# 0   514d83a9e4b0fb270fbdf0e0
# 1   4cb73a61589f236ada423d3d
# 2   55c39c6c498ec87098f437a5
# 3   53d7d0e8498eb348d50d3016
# 4   4f72edd1e4b06e8c1d9aed14
# 5   4d6d360ecb7a8cfa4efa5b79
# 6   4cd02b885b5ca35d69397af0
# 7   5a9987c54940bc2ab2a2f15b
# 8   4cab505876d3a09310162b6b
# 9   4cd2a40b158c5481c6ffafe4
# 10  4c129781a1010f478f244918
# 11  501c35c3e4b004c545239c8a
# 12  539b441f498e78925a2deb36
# 13  594959e83b83074ee07884a6
# 14  4b7198d1f964a520fb4f2de3
# 15  4eabe3d861af01ea2af7c2a6
# 16  4d3f1a7484d46ea8ce51155d
# 17  4cd327759828b60cf702d484
# 18  4d39c583cc48224b69d0364f
# 19  4d1b2e3cdd3637040ac4611a
# 20  5995e2e8a9fe1257eb1a200f
# 21  50fc3c9be4b0ff3fce8f2e1e
# 22  4d582f8c380ab1f7262505f5
# 23  4e3d4ba1d164b52911aa63f4
# 24  4ee48b806da14e7d99cfb376
# 25  4ebad57e77c8100292c1a11b
# 26  4bb77406941ad13a4cb020e3
# 27  512e2566e4b0f2029f6c29b8
# 28  4f22de5fe4b01dc949f6fbdd
# 29  4ed7e3f06da14054c343ea85
# 30  4e4bd8e8d22d8354d6f1e582
# 31  4f54a4eee4b092981036e675
# 32  5b8f0939a4ba7c002c301941
# 33  5f57d220a716fa600c19f7bf
# 34  5d23a4887ad19400236cd6c0
# 35  4c4daaf192b6a59320e3a56e
# 36  4ee476319911944901136a93
# 37  4d1c9f3b7e10a35dc9c80083
# 38  50b185b3e4b08106f37c6417
# 39  5914ad56fdb9a720410c87ab
# 40  4c60168e3986e21eee64934f
# 41  4e76ca51ae60c32851b98966
# 42  4ee0fd7e49010b29921ba016
# 43  532fd03a11d2a4312653803b
# 44  5f10840a268a06488738ccf6
# 45  4d639744a45b5481610f032d
# 46  58c055f90b7e93326677107e
# 47  50f99b00e4b073809e59d1a5
# 48  5b6180586f0aa2002da0e5bc
# 49  4c70096bd274b60c3d4ed80d

# %% [markdown]
# ## Map of Doha with all restaurants within a radius of 12Kms.

# %%
# dataframe_filtered.name
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_96a8df54b33a4e07b253b03ac232333b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_96a8df54b33a4e07b253b03ac232333b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_96a8df54b33a4e07b253b03ac232333b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_96a8df54b33a4e07b253b03ac232333b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B25.2856329%2C51.5264162%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...
